# %%
import pandas as pd

# Load CSV and check the number of rows
df = pd.read_csv('/Users/harishsadasivam/Downloads/diabeteshospital/Book1.csv')
print(len(df))
# Out:
# 46423

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0        149190     55629189        Caucasian  Female  [10-20)
# 1         35754     82637451        Caucasian    Male  [50-60)
# 2         63768    114882984        Caucasian    Male  [70-80)
# 3         28236     89869032  AfricanAmerican  Female  [40-50)
# 4         36900     77391171  AfricanAmerican    Male  [60-70)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  1                         1                    7
# 1                  2                         1                    2
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  2                         1                    4
#
#    time_in_hospital occupation  ...  citoglipton  insulin  \
# 0                 3    Unknown  ...           No       Up
# ...

# %%
print(df.isnull().sum())

df['time_in_hospital'].fillna(df['time_in_hospital'].median(), inplace=True)
df['readmitted'].fillna('Unknown', inplace=True)
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# occupation                  0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# tolbutamide                 0
# pioglitazone                0
# rosiglitazone               0
# ...

# %%
# Get a summary of numerical columns
print(df.describe())
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  4.642300e+04  4.642300e+04       46423.000000
# mean   1.613554e+08  5.759665e+07           2.015143
# std    9.760600e+07  3.692557e+07           1.475931
# min    2.823600e+04  1.350000e+02           1.000000
# 25%    8.619092e+07  2.443052e+07           1.000000
# 50%    1.524036e+08  5.652679e+07           1.000000
# 75%    2.198712e+08  8.909205e+07           3.000000
# max    4.438475e+08  1.894815e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count              46423.000000         46423.000000      46423.000000
# mean                   3.636861             5.933955          4.577968
# std                    5.185812             4.033821          3.003644
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#distribution of time_in_hospital
plt.figure(figsize=(10,6))
sns.histplot(df['time_in_hospital'], kde=True, bins=30)
plt.title('Distribution of Time in Hospital')
plt.xlabel('Time in Hospital')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/Users/harishsadasivam/Downloads/diabeteshospital/Book1.csv')

# Preview the top rows
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0        149190     55629189        Caucasian  Female  [10-20)
# 1         35754     82637451        Caucasian    Male  [50-60)
# 2         63768    114882984        Caucasian    Male  [70-80)
# 3         28236     89869032  AfricanAmerican  Female  [40-50)
# 4         36900     77391171  AfricanAmerican    Male  [60-70)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  1                         1                    7
# 1                  2                         1                    2
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  2                         1                    4
#
#    time_in_hospital occupation  ...  citoglipton  insulin  \
# 0                 3    Unknown  ...           No       Up
# ...

# %%
# Group by 'readmitted' and calculate the average number of diagnoses
readmission_analysis = df.groupby('readmitted')['number_diagnoses'].mean()
print(readmission_analysis)
# Out:
# readmitted
# <30    7.735911
# >30    7.700850
# Name: number_diagnoses, dtype: float64

# %%
print("Shape of the dataset:", df.shape)
df.info()
print("Columns:", df.columns.tolist())
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Shape of the dataset: (46423, 46)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46423 entries, 0 to 46422
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   encounter_id              46423 non-null  int64
#  1   patient_nbr               46423 non-null  int64
#  2   race                      46423 non-null  object
#  3   gender                    46423 non-null  object
#  4   age                       46423 non-null  object
#  5   admission_type_id         46423 non-null  int64
#  6   discharge_disposition_id  46423 non-null  int64
#  7   admission_source_id       46423 non-null  int64
#  8   time_in_hospital          46423 non-null  int64
#  9   occupation                46423 non-null  object
#  10  num_lab_procedures        46423 non-null  int64
#  11  num_procedures            46423 non-null  int64
#  12  num_medications           46423 non-null  int64
# ...

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  4.642300e+04  4.642300e+04       46423.000000
# mean   1.613554e+08  5.759665e+07           2.015143
# std    9.760600e+07  3.692557e+07           1.475931
# min    2.823600e+04  1.350000e+02           1.000000
# 25%    8.619092e+07  2.443052e+07           1.000000
# 50%    1.524036e+08  5.652679e+07           1.000000
# 75%    2.198712e+08  8.909205e+07           3.000000
# max    4.438475e+08  1.894815e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count              46423.000000         46423.000000      46423.000000
# mean                   3.636861             5.933955          4.577968
# std                    5.185812             4.033821          3.003644
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# encounter_id: 46423 unique values
# patient_nbr: 28518 unique values
# race: 6 unique values
# gender: 2 unique values
# age: 10 unique values
# admission_type_id: 7 unique values
# discharge_disposition_id: 23 unique values
# admission_source_id: 13 unique values
# time_in_hospital: 14 unique values
# occupation: 68 unique values
# num_lab_procedures: 111 unique values
# num_procedures: 7 unique values
# num_medications: 71 unique values
# number_outpatient: 39 unique values
# number_emergency: 31 unique values
# number_inpatient: 20 unique values
# diag_1: 611 unique values
# diag_2: 615 unique values
# diag_3: 655 unique values
# number_diagnoses: 14 unique values
# metformin: 4 unique values
# repaglinide: 4 unique values
# nateglinide: 4 unique values
# chlorpropamide: 3 unique values
# glimepiride: 4 unique values
# acetohexamide: 2 unique values
# glipizide: 4 unique values
# glyburide: 4 unique values
# tolbutamide: 2 unique values
# pioglitazone: 4 unique values
# ...

# %%
# View column data types
print(df.dtypes)
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# occupation                  object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# ...

# %%
print(df['age'].dtype)
print(df['age'].unique())
# Out:
# object
# ['[10-20)' '[50-60)' '[70-80)' '[40-50)' '[60-70)' '[80-90)' '[20-30)'
#  '[90-100)' '[30-40)' '[0-10)']

# %%
df['age_num'] = df['age'].str.extract(r'\[(\d+)-').astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/harishsadasivam/Downloads/diabeteshospital/Untitled-3.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/Users/harishsadasivam/Downloads/diabeteshospital/Untitled-3.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> df['age_num'] = df['age'].str.extract(r'\[(\d+)-').astype(int)
#
# NameError: name 'df' is not defined

# %%
print(df['age'].dtype)
print(df['age'].unique())
# Out:
# object
# ['[10-20)' '[50-60)' '[70-80)' '[40-50)' '[60-70)' '[80-90)' '[20-30)'
#  '[90-100)' '[30-40)' '[0-10)']

# %%
df['age_num'] = df['age'].str.extract(r'\[(\d+)-').astype(int)

# %%
df = df[df['age_num'] != 0]

# %%
df.drop(columns=['age'], inplace=True)
df.rename(columns={'age_num': 'age'}, inplace=True)

# %%
print(df['age'].dtype)
print(df['age'].unique())
# Out:
# int64
# [10 50 70 40 60 80 20 90 30]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.countplot(x='age', data=df)
plt.title("Age Distribution")
plt.xlabel("Age (lower bound of range)")
plt.ylabel("Count")
plt.show()

# %%
for col in df.select_dtypes(include='object').columns:
    print(f"\n{col} value counts:")
    print(df[col].value_counts())
# Out:
# race value counts:
# race
# Caucasian          35373
# AfricanAmerican     8682
# Hispanic             840
# Unknown              708
# Other                582
# Asian                224
# Name: count, dtype: int64
#
# gender value counts:
# gender
# Female    25396
# Male      21013
# Name: count, dtype: int64
#
# occupation value counts:
# occupation
# Unknown                             23807
# InternalMedicine                     6292
# Emergency/Trauma                     3831
# Family/GeneralPractice               3494
# Cardiology                           2267
#                                     ...
# Pediatrics-InfectiousDiseases           1
# Pediatrics-EmergencyMedicine            1
# Pediatrics-Hematology-Oncology          1
# Surgery-PlasticwithinHeadandNeck        1
# DCPTEAM                                 1
# Name: count, Length: 68, dtype: int64
#
# diag_1 value counts:
# diag_1
# 428    4053
# 414    2705
# 786    1693
# 486    1679
# 410    1436
#        ...
# ...

# %%
df.groupby('age')['time_in_hospital'].mean().plot(kind='bar', figsize=(8, 4), title="Average Time in Hospital by Age")
plt.ylabel("Avg. Days")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='age', y='number_diagnoses', data=df)
plt.title("Number of Diagnoses by Age")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
readmission_analysis = df.groupby('readmitted')['number_diagnoses'].mean()
print(readmission_analysis)
# Out:
# readmitted
# <30    7.735888
# >30    7.702105
# Name: number_diagnoses, dtype: float64

# %%
from sklearn.cluster import KMeans

# Select relevant columns for clustering
df_clustering = df[['time_in_hospital', 'number_diagnoses', 'age']]

# Standardize the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_clustering_scaled = scaler.fit_transform(df_clustering)

# Fit KMeans with 3 clusters
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(df_clustering_scaled)

# Visualize the clusters
sns.scatterplot(x=df['time_in_hospital'], y=df['number_diagnoses'], hue=df['cluster'], palette='viridis')
plt.title('Patient Clusters Based on Time in Hospital and Number of Diagnoses')
plt.show()

# %%
# Pairplot to show relationships between multiple variables
sns.pairplot(df[['time_in_hospital', 'number_diagnoses', 'age']])
plt.show()

# %%
# Gender distribution
sns.countplot(data=df, x='gender')
plt.title('Gender Distribution of Patients')
plt.show()

# Age distribution 
sns.countplot(data=df, x='age')
plt.title('Age Distribution of Patients')
plt.xticks(rotation=45)
plt.show()

# Race distribution
sns.countplot(data=df, x='race')
plt.title('Race Distribution of Patients')
plt.xticks(rotation=45)
plt.show()

# %%
# Time in hospital vs. readmission status
sns.boxplot(x='readmitted', y='time_in_hospital', data=df)
plt.title('Time in Hospital vs. Readmission')
plt.show()

# Average time in hospital for readmitted patients
readmission_avg = df.groupby('readmitted')['time_in_hospital'].mean()
print(readmission_avg)
# Out:
# readmitted
# <30    4.783359
# >30    4.512799
# Name: time_in_hospital, dtype: float64

# %%
# Most frequent primary diagnosis (diag_1)
top_diag_1 = df['diag_1'].value_counts().head(10)
print(top_diag_1)

# Diagnoses related to readmission
diag_readmission = df.groupby('diag_1')['readmitted'].value_counts().unstack().fillna(0)
print(diag_readmission)
# Out:
# diag_1
# 428    4053
# 414    2705
# 786    1693
# 486    1679
# 410    1436
# 491    1350
# 427    1225
# 996    1031
# 276     966
# 682     950
# Name: count, dtype: int64
# readmitted   <30   >30
# diag_1
# 11           0.0   3.0
# 110          0.0   1.0
# 112         14.0  26.0
# 114          0.0   1.0
# 117          0.0   4.0
# ...          ...   ...
# V58         94.0  67.0
# V60          1.0   0.0
# V63          1.0   1.0
# V67          0.0   1.0
# V71          0.0   2.0
#
# [611 rows x 2 columns]

# %%
# Correlation matrix
corr_matrix = df[['time_in_hospital', 'number_diagnoses', 'age', 'num_lab_procedures']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numeric Features')
plt.show()

# %%
# Gender vs. Number of Diagnoses
sns.boxplot(x='gender', y='number_diagnoses', data=df)
plt.title('Gender vs. Number of Diagnoses')
plt.show()

# Calculate average number of diagnoses by gender
avg_diag_by_gender = df.groupby('gender')['number_diagnoses'].mean()
print(avg_diag_by_gender)
# Out:
# gender
# Female    7.705584
# Male      7.715985
# Name: number_diagnoses, dtype: float64

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Select relevant features for clustering
features = df[['time_in_hospital', 'number_diagnoses']]

# Standardize the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Fit the K-Means model (3 clusters for this example)
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(features_scaled)

# Visualize clusters
sns.scatterplot(data=df, x='time_in_hospital', y='number_diagnoses', hue='cluster', palette='viridis')
plt.title('Patient Clusters Based on Time in Hospital and Number of Diagnoses')
plt.show()

# %%
# Calculate the mean time in hospital and number of diagnoses for each cluster
cluster_analysis = df.groupby('cluster')[['time_in_hospital', 'number_diagnoses']].mean()
print(cluster_analysis)
# Out:
#          time_in_hospital  number_diagnoses
# cluster
# 0                9.327525          8.399917
# 1                3.481356          8.652340
# 2                3.033103          5.261048

# %%
pip install nbconvert PyPDF2
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
